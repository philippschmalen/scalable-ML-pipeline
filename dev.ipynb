# %% [markdown]
# # Preprocessing
# ---

# %% [markdown]
# ## Clean data

# %%
import pandas as pd 

def clean_data(file_input='data/census.csv', file_output='data/census_clean.csv'):
    df_raw = pd.read_csv(file_input)
    (df_raw
        .drop_duplicates()
        .dropna()
    ).to_csv(file_output, index=False)

clean_data()

# %% [markdown]
# ## EDA

# %%
from pandas_profiling import ProfileReport

def load_data(file_input='data/census_clean.csv'):
    return pd.read_csv(file_input)

df = load_data()

profile = ProfileReport(df)
profile.to_file("reports/census_eda.html")
# Out:
# Summarize dataset: 100%|██████████| 64/64 [00:12<00:00,  5.33it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:06<00:00,  6.22s/it]
# Render HTML: 100%|██████████| 1/1 [00:02<00:00,  2.34s/it]
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 47.53it/s]

# %% [markdown]
# # ML pipeline
# ---

# %%
from src.ml.data import load_config
from src.ml.data import preprocess
from src.ml.model import train_model
from src.ml.model import create_automl_pipeline
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import label_binarize

# load config
config = load_config()

# load data & preprocess
X, y = preprocess(config)

# train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=config['data']['test_size'],
    random_state=config['data']['random_state']
)

pipeline = create_automl_pipeline(config)

settings_automl = {
    "automl__task": config["automl"]["task"],
    "automl__metric": config["automl"]["metric"],
    "automl__log_training_metric": config["automl"]["log_training_metric"],
    "automl__log_file_name": f"logs/flaml.log", 
    "automl__time_budget": config["automl"]["time_budget"],
    "automl__seed": config["automl"]["random_state"],
    "automl__estimator_list": config["automl"]["estimator_list"]
}
pipeline.fit(X_train, y_train, **settings_automl)
# Out:
# [flaml.automl: 11-03 09:34:21] {1463} INFO - Data split method: stratified
# INFO:flaml.automl:Data split method: stratified
# [flaml.automl: 11-03 09:34:21] {1467} INFO - Evaluation method: holdout
# INFO:flaml.automl:Evaluation method: holdout
# [flaml.automl: 11-03 09:34:21] {1515} INFO - Minimizing error metric: 1-roc_auc
# INFO:flaml.automl:Minimizing error metric: 1-roc_auc
# [flaml.automl: 11-03 09:34:21] {1552} INFO - List of ML learners in AutoML Run: ['lgbm']
# INFO:flaml.automl:List of ML learners in AutoML Run: ['lgbm']
# [flaml.automl: 11-03 09:34:21] {1793} INFO - iteration 0, current learner lgbm
# INFO:flaml.automl:iteration 0, current learner lgbm
# [flaml.automl: 11-03 09:34:21] {1910} INFO - Estimated sufficient time budget=922s. Estimated necessary time budget=1s.
# INFO:flaml.automl:Estimated sufficient time budget=922s. Estimated necessary time budget=1s.
# [flaml.automl: 11-03 09:34:21] {1981} INFO -  at 0.2s,	estimator lgbm's best error=0.1454,	best estimator lgbm's best error=0.1454
# INFO:flaml.automl: at 0.2s,	estimator lgbm's best error=0.1454,	best estimator lgbm's best error=0.1454
# [flaml.automl: 11-03 09:34:21] {1793} INFO - iteration 1, current learner lgbm
# INFO:flaml.automl:iteration 1, current learner lgbm
# [flaml.automl: 11-03 09:34:21] {1981} INFO -  at 0.3s,	estimator lgbm's best error=0.1430,	best estimator lgbm's best error=0.1430
# INFO:flaml.automl: at 0.3s,	estimator lgbm's best error=0.1430,	best estimator lgbm's best error=0.1430
# [flaml.automl: 11-03 09:34:21] {1793} INFO - iteration 2, current learner lgbm
# INFO:flaml.automl:iteration 2, current learner lgbm
# [flaml.automl: 11-03 09:34:21] {1981} INFO -  at 0.4s,	estimator lgbm's best error=0.1430,	best estimator lgbm's best error=0.1430
# INFO:flaml.automl: at 0.4s,	estimator lgbm's best error=0.1430,	best estimator lgbm's best error=0.1430
# [flaml.automl: 11-03 09:34:21] {1793} INFO - iteration 3, current learner lgbm
# INFO:flaml.automl:iteration 3, current learner lgbm
# [flaml.automl: 11-03 09:34:22] {1981} INFO -  at 0.5s,	estimator lgbm's best error=0.1076,	best estimator lgbm's best error=0.1076
# INFO:flaml.automl: at 0.5s,	estimator lgbm's best error=0.1076,	best estimator lgbm's best error=0.1076
# [flaml.automl: 11-03 09:34:22] {1793} INFO - iteration 4, current learner lgbm
# INFO:flaml.automl:iteration 4, current learner lgbm
# [flaml.automl: 11-03 09:34:22] {1981} INFO -  at 0.7s,	estimator lgbm's best error=0.1076,	best estimator lgbm's best error=0.1076
# INFO:flaml.automl: at 0.7s,	estimator lgbm's best error=0.1076,	best estimator lgbm's best error=0.1076
# [flaml.automl: 11-03 09:34:22] {1793} INFO - iteration 5, current learner lgbm
# INFO:flaml.automl:iteration 5, current learner lgbm
# [flaml.automl: 11-03 09:34:22] {1981} INFO -  at 0.8s,	estimator lgbm's best error=0.0961,	best estimator lgbm's best error=0.0961
# INFO:flaml.automl: at 0.8s,	estimator lgbm's best error=0.0961,	best estimator lgbm's best error=0.0961
# [flaml.automl: 11-03 09:34:22] {1793} INFO - iteration 6, current learner lgbm
# INFO:flaml.automl:iteration 6, current learner lgbm
# [flaml.automl: 11-03 09:34:22] {1981} INFO -  at 0.9s,	estimator lgbm's best error=0.0961,	best estimator lgbm's best error=0.0961
# INFO:flaml.automl: at 0.9s,	estimator lgbm's best error=0.0961,	best estimator lgbm's best error=0.0961
# [flaml.automl: 11-03 09:34:22] {1793} INFO - iteration 7, current learner lgbm
# INFO:flaml.automl:iteration 7, current learner lgbm
# [flaml.automl: 11-03 09:34:22] {1981} INFO -  at 1.1s,	estimator lgbm's best error=0.0961,	best estimator lgbm's best error=0.0961
# INFO:flaml.automl: at 1.1s,	estimator lgbm's best error=0.0961,	best estimator lgbm's best error=0.0961
# [flaml.automl: 11-03 09:34:22] {1793} INFO - iteration 8, current learner lgbm
# INFO:flaml.automl:iteration 8, current learner lgbm
# [flaml.automl: 11-03 09:34:22] {1981} INFO -  at 1.3s,	estimator lgbm's best error=0.0889,	best estimator lgbm's best error=0.0889
# INFO:flaml.automl: at 1.3s,	estimator lgbm's best error=0.0889,	best estimator lgbm's best error=0.0889
# [flaml.automl: 11-03 09:34:22] {1793} INFO - iteration 9, current learner lgbm
# INFO:flaml.automl:iteration 9, current learner lgbm
# [flaml.automl: 11-03 09:34:22] {1981} INFO -  at 1.4s,	estimator lgbm's best error=0.0889,	best estimator lgbm's best error=0.0889
# INFO:flaml.automl: at 1.4s,	estimator lgbm's best error=0.0889,	best estimator lgbm's best error=0.0889
# [flaml.automl: 11-03 09:34:22] {1793} INFO - iteration 10, current learner lgbm
# INFO:flaml.automl:iteration 10, current learner lgbm
# [flaml.automl: 11-03 09:34:23] {1981} INFO -  at 1.6s,	estimator lgbm's best error=0.0889,	best estimator lgbm's best error=0.0889
# INFO:flaml.automl: at 1.6s,	estimator lgbm's best error=0.0889,	best estimator lgbm's best error=0.0889
# [flaml.automl: 11-03 09:34:23] {1793} INFO - iteration 11, current learner lgbm
# INFO:flaml.automl:iteration 11, current learner lgbm
# [flaml.automl: 11-03 09:34:23] {1981} INFO -  at 1.7s,	estimator lgbm's best error=0.0889,	best estimator lgbm's best error=0.0889
# INFO:flaml.automl: at 1.7s,	estimator lgbm's best error=0.0889,	best estimator lgbm's best error=0.0889
# [flaml.automl: 11-03 09:34:23] {1793} INFO - iteration 12, current learner lgbm
# INFO:flaml.automl:iteration 12, current learner lgbm
# [flaml.automl: 11-03 09:34:23] {1981} INFO -  at 1.9s,	estimator lgbm's best error=0.0820,	best estimator lgbm's best error=0.0820
# INFO:flaml.automl: at 1.9s,	estimator lgbm's best error=0.0820,	best estimator lgbm's best error=0.0820
# [flaml.automl: 11-03 09:34:23] {1793} INFO - iteration 13, current learner lgbm
# INFO:flaml.automl:iteration 13, current learner lgbm
# [flaml.automl: 11-03 09:34:23] {1981} INFO -  at 2.1s,	estimator lgbm's best error=0.0769,	best estimator lgbm's best error=0.0769
# INFO:flaml.automl: at 2.1s,	estimator lgbm's best error=0.0769,	best estimator lgbm's best error=0.0769
# [flaml.automl: 11-03 09:34:23] {1793} INFO - iteration 14, current learner lgbm
# INFO:flaml.automl:iteration 14, current learner lgbm
# [flaml.automl: 11-03 09:34:23] {1981} INFO -  at 2.3s,	estimator lgbm's best error=0.0769,	best estimator lgbm's best error=0.0769
# INFO:flaml.automl: at 2.3s,	estimator lgbm's best error=0.0769,	best estimator lgbm's best error=0.0769
# [flaml.automl: 11-03 09:34:23] {1793} INFO - iteration 15, current learner lgbm
# INFO:flaml.automl:iteration 15, current learner lgbm
# [flaml.automl: 11-03 09:34:24] {1981} INFO -  at 2.5s,	estimator lgbm's best error=0.0699,	best estimator lgbm's best error=0.0699
# INFO:flaml.automl: at 2.5s,	estimator lgbm's best error=0.0699,	best estimator lgbm's best error=0.0699
,	estimator lgbm's best error=0.0656,	best estimator lgbm's best error=0.0656
# INFO:flaml.automl: at 29.6s,	estimator lgbm's best error=0.0656,	best estimator lgbm's best error=0.0656
# [flaml.automl: 11-03 09:34:51] {2087} INFO - selected model: LGBMClassifier(colsample_bytree=0.42744409921417026,
#                learning_rate=0.19034869851630634, max_bin=63,
#                min_child_samples=10, n_estimators=158, num_leaves=13,
#                reg_alpha=0.021305299266143003, reg_lambda=1.9158966386091625,
#                verbose=-1)
# INFO:flaml.automl:selected model: LGBMClassifier(colsample_bytree=0.42744409921417026,
#                learning_rate=0.19034869851630634, max_bin=63,
#                min_child_samples=10, n_estimators=158, num_leaves=13,
#                reg_alpha=0.021305299266143003, reg_lambda=1.9158966386091625,
#                verbose=-1)
# [flaml.automl: 11-03 09:34:51] {2149} INFO - retrain lgbm for 0.4s
# INFO:flaml.automl:retrain lgbm for 0.4s
# [flaml.automl: 11-03 09:34:51] {2155} INFO - retrained model: LGBMClassifier(colsample_bytree=0.42744409921417026,
#                learning_rate=0.19034869851630634, max_bin=63,
#                min_child_samples=10, n_estimators=158, num_leaves=13,
#                reg_alpha=0.021305299266143003, reg_lambda=1.9158966386091625,
#                verbose=-1)
# INFO:flaml.automl:retrained model: LGBMClassifier(colsample_bytree=0.42744409921417026,
#                learning_rate=0.19034869851630634, max_bin=63,
#                min_child_samples=10, n_estimators=158, num_leaves=13,
#                reg_alpha=0.021305299266143003, reg_lambda=1.9158966386091625,
#                verbose=-1)
# [flaml.automl: 11-03 09:34:51] {1576} INFO - fit succeeded
# INFO:flaml.automl:fit succeeded
# [flaml.automl: 11-03 09:34:51] {1577} INFO - Time taken to find the best model: 20.26280641555786
# INFO:flaml.automl:Time taken to find the best model: 20.26280641555786
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value='missing',
#                                                                                  strategy='constant')),
#                                                                   ('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['workclass', 'education',
#                                                    'marital-status',
#                                                    'occupation', 'relationship',
#                                                    'race', 'sex',
#                                                    'native-country']),
#                                                  ('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value=0,
#                                                                                  strategy='constant')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['age', 'fnlgt',
#                                                    'education-num',
#                                                    'capital-gain',
#                                                    'capital-loss',
#                                                    'hours-per-week'])])),
#                 ('automl', <flaml.automl.AutoML object at 0x0000028184A7C4C0>)])

# %% [markdown]
# # API
# ---

# %%
from src.ml.data import load_config
from src.ml.data import preprocess
from src.ml.model import load_model
import json
import pandas as pd
from pprint import pprint


config = load_config()
X, y = preprocess(config)
model = load_model()

X_test = json.dumps(X.sample(1).to_dict(orient='records')[0])

X_pred = pd.DataFrame(json.loads(X_test), index=[0])
model.predict(X_pred)
# Out:
#    age workclass  fnlgt education  education-num      marital-status  \
# 0   51   Private  22211   Masters             14  Married-civ-spouse
#
#        occupation relationship   race   sex  capital-gain  capital-loss  \
# 0  Prof-specialty      Husband  White  Male             0          1902
#
#    hours-per-week native-country
# 0              60  United-States
# array([1])

# %%
pprint(X.sample(1).to_dict(orient='records')[0])
# Out:
# {'age': 41,
#  'capital-gain': 0,
#  'capital-loss': 0,
#  'education': '12th',
#  'education-num': 8,
#  'fnlgt': 327606,
#  'hours-per-week': 40,
#  'marital-status': 'Separated',
#  'native-country': 'United-States',
#  'occupation': 'Craft-repair',
#  'race': 'Black',
#  'relationship': 'Not-in-family',
#  'sex': 'Male',
#  'workclass': 'Private'}

# %% [markdown]
# # Tests
#
# ---

# %% [markdown]
# ## Model

# %%
from flaml import AutoML
from src.ml.data import load_config
from src.ml.model import create_automl_pipeline

config = load_config()

# %% [markdown]
# ## Data
